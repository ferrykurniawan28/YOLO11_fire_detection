# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")

# %%
model.train(data="data.yaml", epochs=15, batch=16, imgsz=320)
# Out:
# Ultralytics 8.3.50 🚀 Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3902MiB)
# ...

# %%
model.predict("outdoors.png", save=True, imgsz=320)
# Out:
# image 1/1 /home/safer/Desktop/yolo/outdoors.png: 224x320 2 fires, 48.3ms
# Speed: 0.9ms preprocess, 48.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 320)
# Results saved to runs/detect/train2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'fire'}
#  obb: None
#  orig_img: array([[[42, 74, 72],
#          [41, 74, 72],
#          [41, 72, 69],
#          ...,
#          [72, 70, 69],
#          [71, 69, 66],
#          [70, 68, 63]],
#
#         [[41, 72, 72],
#          [41, 72, 70],
#          [39, 70, 67],
#          ...,
#          [72, 68, 67],
#          [72, 69, 66],
#          [70, 66, 63]],
#
#         [[43, 74, 71],
#          [39, 69, 67],
#          [37, 68, 65],
#          ...,
#          [71, 67, 66],
#          [72, 66, 63],
#          [68, 64, 61]],
#
#         ...,
#
#         [[63, 57, 57],
#          [63, 58, 58],
# ...

# %%
# continue training

model2 = YOLO("runs/detect/train/weights/best.pt")

# %%
model2.train(data="data.yaml", epochs=15, batch=16, imgsz=320, lr0=0.001)
# Out:
# Ultralytics 8.3.50 🚀 Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3902MiB)
# ...

# %%
results = model2.predict("outdoors.png", save=True, imgsz=320)
# Out:
# image 1/1 /home/safer/Desktop/yolo/outdoors.png: 224x320 1 fire, 6.7ms
# Speed: 7.2ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
# Results saved to runs/detect/train32

# %%
model3 = YOLO("runs/detect/train3/weights/best.pt")

# %%
model3.train(data="data.yaml", epochs=15, batch=16, imgsz=320, lr0=0.0001, dropout=0.3)
# Out:
# Ultralytics 8.3.50 🚀 Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3902MiB)
# ...

# %%
# predict with best model
results = model3.predict("outdoors.png", save=True, imgsz=320)
# Out:
# image 1/1 /home/safer/Desktop/yolo/outdoors.png: 224x320 1 fire, 792.9ms
# Speed: 790.6ms preprocess, 792.9ms inference, 20.1ms postprocess per image at shape (1, 3, 224, 320)
# Results saved to runs/detect/train42

# %%
model4 = YOLO("runs/detect/train4/weights/best.pt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model4 = YOLO("runs/detect/train4/weights/best.pt")
#
# NameError: name 'YOLO' is not defined

# %%
model4.train(data="data.yaml", epochs=20, batch=16, imgsz=320, lr0=0.0001, dropout=0.3)
# Out:
# Ultralytics 8.3.50 🚀 Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3902MiB)
# ...

# %%
from ultralytics import YOLO

# %%
model4 = YOLO("runs/detect/train4/weights/best.pt")

# %%
model4.train(data="data.yaml", epochs=15, batch=16, imgsz=320, lr0=0.00001, dropout=0.3)
# Out:
# New https://pypi.org/project/ultralytics/8.3.53 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.50 🚀 Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3902MiB)
# ...

# %%
model4.train(data="data.yaml", epochs=15, batch=16, imgsz=320, lr0=0.00001, dropout=0.3, optimizer="SGD")
# Out:
# New https://pypi.org/project/ultralytics/8.3.53 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.50 🚀 Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3902MiB)
# ...

# %%
model4.train(data="data.yaml", epochs=15, batch=16, imgsz=320, lr0=0.00001, dropout=0.3, optimizer="SGD", momentum=0.9)
# Out:
# New https://pypi.org/project/ultralytics/8.3.53 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.50 🚀 Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3902MiB)
# ...

# %%
model4.train(data="data.yaml", epochs=15, batch=16, imgsz=320, lr0=0.0001, lrf=0.00001, dropout=0.3, optimizer="AdamW", momentum=0.9)
# Out:
# New https://pypi.org/project/ultralytics/8.3.53 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.50 🚀 Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3902MiB)
# ...

# %%
new_model = YOLO("runs/detect/train/weights/best.pt")
results = new_model.predict("images.jpeg", save=True, imgsz=320)
# Out:
# image 1/1 /home/safer/Desktop/yolo/images.jpeg: 256x320 2 fires, 16.4ms
# Speed: 0.7ms preprocess, 16.4ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 320)
# Results saved to runs/detect/predict9
